# %%
a=int(input('Enter a number: '))
b=int(input('Enter a number: '))
c=int(input('Enter a number: ')) 
if(a>=b):
    if(a>=c):
        greatest=a
    else:
        greatest=c
else:
    if(b>=c):
        greatest=b
    else:
        greatest=c
    print(str(greatest)+' is the greatest number')
# Out:
# 60 is the greatest number

# %%
a,b,c=eval(input("Enter three subjects' marks: "))
avg=(a+b+c)/3
print('Average of three subject marks is:' + str(avg))
if(avg>=80):
    print('You are an outstanding student!')
elif(avg>=80):
    print('You are a good student!')
elif(avg>=60):
    print('You are an average student!')
elif(avg>=50):
    print('You are a below average student!')
elif(avg>=40):
    print('You are a poor student!')
else:
    print('You need extra ordinary efforts!')
# Out:
# Average of three subject marks is:56.666666666666664
# You are a below average student!

# %%
test1,test2,test3,test4=eval(input("Enter four  test scores: "))
avg=(test1+test2+test3+test4)/4
print("Average of four test score"+str(avg))
if avg >= 80:
    print("you are an outstanding student")
else:
    if avg >= 70:
        print("you are a good student")
    else:
        if avg >= 60:
            print("you are an average student")
        else:
            if avg >= 50:
                print("you are a below average student")
            else:
                if avg >= 40:
                    print("you are a poor student")
                else:
                    print("you need extra ordinary efforts")
# Out:
# Average of four test score47.0
# you are a poor student
